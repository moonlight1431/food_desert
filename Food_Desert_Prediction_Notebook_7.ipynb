# %% [markdown]
# <a href="https://colab.research.google.com/github/moonlight1431/food_desert/blob/main/Food_Desert_Prediction_Notebook_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Notebook #7: THE DATA SCIENCE PIPELINE**#
# ---
# Please make a copy of this notebook and add it the Notebook #7 folder under the Completed Notebooks folder on the Google Drive and rename the notebook as "FirstName LastName - Food Desert Prediction - Notebook #7"

# %% [markdown]
# We've been learning about all of these different data science and ML tools and libraries, and now it's time to put it all together and build our food desert prediction model!

# %% [markdown]
# ## Choosing the Dataset##
#
# We have two different datasets to choose from, and there are multiple ways that each team can work on the dataset.
#
# Here are our options:
#
#
# *   Each team works on a different dataset (one on the Feeding America and one on the USDA Food Access Research Atlas)
# *   Each team works on the merged datasets (both of the above datasets merged together)
# *   Both teams work on the same dataset (either the Feeding America or the USDA one)
#
# Team 1: USDA Food Access Research Atlas

# %% [markdown]
# Let's load our dataset!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, mean_squared_error, r2_score


# Define the local file path
file_path = '/content/drive/MyDrive/DataGood Food Desert Prediction Project/Food Desert Datasets/...'

# Create the dataframe
df = pd.read_csv(file_path)
df.head()

# %% [markdown]
# ## Data Science Pipeline ##
#
# Now it's time for us to go through the data science pipeline!

# %% [markdown]
# ### Data Cleaning ###
#
# First, let's clean our data!

# %%
# Do any data cleaning steps here, such as dropping irrelevant columns, removing/replacing null values
# Note: if using the merged dataset, it might be a good idea to use the mean of the values instead of removing them
...

# %% [markdown]
# ### EDA ###
#
# Play around with the dataset a bit more and try and see what columns or anything of the sort can be useful for predicting a food desert.

# %%
# Look back at Notebook 4 for some ideas, such as plotting correlation matrices or line graphs!
...

# %%
# Feel free to add multiple cells to explore the dataset!

# %% [markdown]
# ### Feature Engineering + Feature Selection
#
# After EDA, we have an idea of what features can be used to train the model,so next we have to select which features we should use to train the model, and what our target variable will be.
#
# Feature engineering involves transforming raw data into  inputs that can enhance model performance including creating new variables, **one hot encoding** for categorical data, or scaling numerical values. (Take a look back at Notebook #6 for this)
#
# Once potential features are engineered, feature selection helps us identify the most relevant ones for training the model. By selecting features that are most predictive of our target variable and removing redundant or irrelevant ones, we reduce overfitting, improve model accuracy, and enhance interpretability.

# %%
# Try doing some feature engineering!

# %% [markdown]
# One of the features that can be helpful is using clusters from K-Means Clustering or DBSCAN as a feature for the model.
#
# For the Feeding America dataset:
# 1. Select relevant features (e.g., food insecurity rates, cost per meal, child FI rate, SNAP-related metrics).
# 2. Normalize or standardize the features.
#
# 3. Try different values of k and use the elbow method or silhouette score to find the optimal number of clusters.
#
# 4. Once you choose a k, assign cluster labels to each county
#
# 5. Look at average features for each cluster
#
# 6. Treat the cluster label as a feature for the model by adding it as a column on the dataset.
#
# For the USDA dataset you can use features like: PovertyRate, LowIncomeTracts. HUNVFlag lawhitehalfshare, etc.

# %%
# Try it out!
...

# %% [markdown]
# To even use the model, we need to figure out what our target variable should be (our Y in the model), basically defining what should be classified as a food desert.
#
# Some examples could be LILATracts_1And10, LILATracts_halfAnd10 column (or maybe manipulating these into a better target variable) for the USDA dataset, or for the Feeding America dataset, when the food insecure rate is above 17.4%.

# %%
# Define the target variable
Y_food_desert = df[...]

# %% [markdown]
# ### Training and Testing the Model ###
# Now it's time to actually build our model. Take a look back at Notebook #5 if you forgot!

# %%
X_train, X_test, y_train, y_test = train_test_split(...)

# You might also want to standardize the features!

# %%
# Let's train the model!
rf_model = RandomForestClassifier(...)
rf_model.fit(...)

#Make predictions
y_pred = rf_model.predict(...)

# %% [markdown]
# ### Model Performance ###
#
# We've finally built the model! But how do we know how accurate it is?
# To do that, we need to evaluate its accuracy and see how well it predicts food deserts.
#
# Take a look at Notebook #6 for some examples and features we can use to evaluate the performance!

# %%
# Try evaluating the accuracy or precision, or maybe build a confusion matrix!
...

# %%
# Maybe do some feature importance analysis too!

# %% [markdown]
# If your model isn't exactly meeting the accuracy standards you wanted to reach, try going back to the EDA + Feature Engineering/Selection stage to explore and try out some new features!

# %% [markdown]
# # Congrats! You've finished building the model! #
#
# If you want to add this, and the other notebooks onto GitHub, go on to GitHub and create a new repository. After you create the repository, follow the instruction on GitHub to set up the repository so it creates the 'main' branch. When you're done with that, go through the notebooks you've done and select "File" on the top left. The menu should show an option saying "Save a copy on GitHub" and follow the instructions. Congrats! You should be able to save all of your notebooks on GitHub!

# %% [markdown]
# # Congratulations for finishing this notebook! #
# ![image.png](data:image/png;base64,...)
#
#
# Enjoy this quokka!
